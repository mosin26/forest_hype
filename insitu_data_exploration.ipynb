# %%
import shapefile
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
pp1_path = '/Users/vasilii.mosin/Desktop/Research/shapes/to_send_data/pp_1_trees_geometry.shp'
sf = shapefile.Reader(pp1_path)
fields = [x[0] for x in sf.fields[1:]]
records = sf.records()
pp1 = pd.DataFrame(data=np.array(records), columns=fields)
pp1.head()
# Out:
#   id_tree OBJECTID_1 name_squar letter index id_square n_trees specie     d  \
# 0       1          1         A1      A     1         1       1      E  32.6
# 1       2          2         A1      A     1         1       2      E  13.2
# 2       3          3         A1      A     1         1       3      E  20.2
# 3       4          4         A1      A     1         1       4      E  31.2
# 4       5          5         A1      A     1         1       5      Б  19.1
#
#   ktg    X    Y comment add_class
# 0   1  4.7  0.3
# 1   1  1.6  0.8
# 2   1  4.7  2.1
# 3   1  1.6  2.0
# 4   4  3.2  2.6

# %%
pp2_path = '/Users/vasilii.mosin/Desktop/Research/shapes/to_send_data/pp_2_trees_geometry.shp'
sf = shapefile.Reader(pp2_path)
fields = [x[0] for x in sf.fields[1:]]
records = sf.records()
pp2 = pd.DataFrame(data=np.array(records), columns=fields)
pp2.head()
# Out:
#   id_tree OBJECTID_1 name_squar letter index id_square n_trees ktg specie  \
# 0       1          1         A1      A     1         1       1   3      б
# 1       2          2         A1      A     1         1       2   1      е
# 2       3          3         A1      A     1         1       3   1      е
# 3       4          4         A1      A     1         1       4   1      е
# 4       5          5         A1      A     1         1       5   1      е
#
#       d    X    Y commnet add_class
# 0  17.3  2.8  0.0
# 1  14.9  5.7  0.6
# 2  12.5  1.0  1.3
# 3  31.9  4.4  1.7
# 4  29.9  8.8  2.1

# %%
pp3_path = '/Users/vasilii.mosin/Desktop/Research/shapes/to_send_data/pp_3_trees_geometry.shp'
sf = shapefile.Reader(pp3_path)
fields = [x[0] for x in sf.fields[1:]]
records = sf.records()
pp3 = pd.DataFrame(data=np.array(records), columns=fields)
pp3.head()
# Out:
#   id_tree OBJECTID_1 name_squar letter index id_square n_tree ktg  specie  \
# 0       1          1         A1      A     1         1      1   1     El'
# 1       2          2         A1      A     1         1      2   3  Bereza
# 2       3          3         A1      A     1         1      3   1     El'
# 3       4          4         A1      A     1         1      4   3     El'
# 4       5          5         A1      A     1         1      5   2     El'
#
#       d    X    Y comment add_class
# 0  12.3  0.4  9.6
# 1  22.5  1.9  9.7
# 2  21.7  1.5  4.6
# 3  16.1  4.3  0.5
# 4  19.0  6.2  3.5

# %%
pp4_path = '/Users/vasilii.mosin/Desktop/Research/shapes/to_send_data/pp_4_trees_geometry.shp'
sf = shapefile.Reader(pp4_path)
fields = [x[0] for x in sf.fields[1:]]
records = sf.records()
pp4 = pd.DataFrame(data=np.array(records), columns=fields)
pp4.head()
# Out:
#   id_tree OBJECTID_1 name_squar letter index id_square n_tree ktg  specie  \
# 0       1          1         A1      A     1         1      1   1     El'
# 1       2          2         A1      A     1         1      2   1     El'
# 2       3          3         A1      A     1         1      3   3  Bereza
# 3       4          4         A1      A     1         1      4   1     El'
# 4       5          5         A1      A     1         1      5   1     El'
#
#       d    X    Y comment add_class
# 0  28.6  2.1  0.7
# 1  31.3  1.7  4.1
# 2  13.1  0.5  5.8
# 3  24.6  1.9  8.0
# 4  28.7  1.5  8.4

# %%
pp4['specie'].value_counts()
# Out:
# El'        528
# Bereza     153
# Pichta       7
# Iva dre      1
# Name: specie, dtype: int64
