# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# %matplotlib notebook

# %%
plt.style.use('seaborn-whitegrid')

# %%
REFERENCE_PATH = '/Users/vasilii.mosin/Desktop/Research/forest/data/hyperspectral/reference/Krasnoborsk_Aug_2018/'

# %% [markdown]
# ## Flight 1 (changing from clouds to haze)

# %%
birch_field = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F1_birch.txt', sep="\t")

# %%
birch_field.head()
# Out:
#    Wavelength  F1_birch_00000.asd  F1_birch_00001.asd  F1_birch_00002.asd  \
# 0         350            0.970279            0.011777            0.014122
# 1         351            0.975285            0.011718            0.015013
# 2         352            0.975776            0.013517            0.017044
# 3         353            0.971351            0.015680            0.018160
# 4         354            0.973514            0.016911            0.016965
#
#    F1_birch_00003.asd  F1_birch_00004.asd  F1_birch_00005.asd  \
# 0            0.012473            0.014364            0.010646
# 1            0.013477            0.013921            0.011978
# 2            0.015993            0.015960            0.014131
# 3            0.017216            0.017596            0.015212
# 4            0.013497            0.017206            0.014429
#
#    F1_birch_00006.asd  F1_birch_00007.asd  F1_birch_00008.asd  \
# 0            0.014688            0.016107            0.014638
# ...

# %%
START_LIMIT = 0
END_LIMIT = 1000

plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00005.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00006.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00007.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00008.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00009.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00010.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Birch FieldSpec3 (Flight 1)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="898">

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00005.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00006.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00007.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00008.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00009.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F1_birch_00010.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Birch FieldSpec3 (Flight 1)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="951">

# %%
birch_usb_1 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F1_birch/points/1/1-1.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
birch_usb_2 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F1_birch/points/1/1-2.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
birch_usb_3 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F1_birch/points/1/1-3.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
birch_usb_4 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F1_birch/points/1/1-4.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
birch_usb_5 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F1_birch/points/1/1-5.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)

# %%
birch_usb_5.head()
# Out:
#         W          D          R          S          P
# 0  340.28  476.29900  467.63900  575.30365  14873.403
# 1  340.66  476.29900  467.63900  575.30365  14873.403
# 2  341.03  476.29900  467.63900  575.30365  14873.403
# 3  341.41  476.29900  467.63900  575.30365  14873.403
# 4  341.78  480.62903  492.21466  455.93637      0.000

# %%
START_LIMIT = 296
END_LIMIT = 1626

plt.plot(birch_usb_1['W'][START_LIMIT:END_LIMIT], birch_usb_1['P'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Birch USB2000+ (Flight 1)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="924">

# %%
START_LIMIT = 296
END_LIMIT = 1626

plt.plot(birch_usb_1['W'][START_LIMIT:END_LIMIT], birch_usb_1['P'][START_LIMIT:END_LIMIT])
plt.plot(birch_usb_2['W'][START_LIMIT:END_LIMIT], birch_usb_2['P'][START_LIMIT:END_LIMIT])
plt.plot(birch_usb_3['W'][START_LIMIT:END_LIMIT], birch_usb_3['P'][START_LIMIT:END_LIMIT])
plt.plot(birch_usb_4['W'][START_LIMIT:END_LIMIT], birch_usb_4['P'][START_LIMIT:END_LIMIT])
plt.plot(birch_usb_5['W'][START_LIMIT:END_LIMIT], birch_usb_5['P'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Birch USB2000+ (Flight 1)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="882">

# %% [markdown]
# ## Flight 2 (clouds with rain start to drop)

# %%
birch_field = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F2_birch.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00005.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00006.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00007.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00008.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00009.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_field['F2_birch_00010.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Birch FieldSpec3 (Flight 2)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="875">

# %%
birch_usb_1 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_birch/points/1/1-1.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
birch_usb_2 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_birch/points/1/1-2.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
birch_usb_3 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_birch/points/1/1-3.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
birch_usb_4 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_birch/points/1/1-4.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
birch_usb_5 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_birch/points/1/1-5.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)

# %%
START_LIMIT = 296
END_LIMIT = 1626

plt.plot(birch_usb_1['W'][START_LIMIT:END_LIMIT], birch_usb_1['P'][START_LIMIT:END_LIMIT])
plt.plot(birch_usb_2['W'][START_LIMIT:END_LIMIT], birch_usb_2['P'][START_LIMIT:END_LIMIT])
plt.plot(birch_usb_3['W'][START_LIMIT:END_LIMIT], birch_usb_3['P'][START_LIMIT:END_LIMIT])
plt.plot(birch_usb_4['W'][START_LIMIT:END_LIMIT], birch_usb_4['P'][START_LIMIT:END_LIMIT])
plt.plot(birch_usb_5['W'][START_LIMIT:END_LIMIT], birch_usb_5['P'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Birch USB2000+ (Flight 2)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="949">

# %%
spruce_field = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F2_spruce.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00005.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00006.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00007.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00008.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00009.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_field['F2_spoose_00010.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Spruce FieldSpec3 (Flight 2)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="874">

# %%
spruce_usb_1 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_spruce/points/1/1-1.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
spruce_usb_2 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_spruce/points/1/1-2.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
spruce_usb_3 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_spruce/points/1/1-3.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
spruce_usb_4 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_spruce/points/1/1-4.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)
spruce_usb_5 = pd.read_csv(REFERENCE_PATH+'USB2000/2018.08.21_Kotlas/F2_spruce/points/1/1-5.gmy', header=16, sep='\t',
            engine='python', skipfooter=1)

# %%
START_LIMIT = 296
END_LIMIT = 1626

plt.plot(spruce_usb_1['W'][START_LIMIT:END_LIMIT], spruce_usb_1['P'][START_LIMIT:END_LIMIT])
plt.plot(spruce_usb_2['W'][START_LIMIT:END_LIMIT], spruce_usb_2['P'][START_LIMIT:END_LIMIT])
plt.plot(spruce_usb_3['W'][START_LIMIT:END_LIMIT], spruce_usb_3['P'][START_LIMIT:END_LIMIT])
plt.plot(spruce_usb_4['W'][START_LIMIT:END_LIMIT], spruce_usb_4['P'][START_LIMIT:END_LIMIT])
plt.plot(spruce_usb_5['W'][START_LIMIT:END_LIMIT], spruce_usb_5['P'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Spruce USB2000+ (Flight 2)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="934">

# %%
START_LIMIT = 100
END_LIMIT = 550

spruce_mean = spruce_field.iloc[:,2:12].mean(1)
spruce_std = spruce_field.iloc[:,2:12].std(1)
birch_mean = birch_field.iloc[:,2:12].mean(1)
birch_std = birch_field.iloc[:,2:12].std(1)

plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], spruce_mean[START_LIMIT:END_LIMIT], label='Spruce')
plt.fill_between(spruce_field['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]+spruce_std[START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]-spruce_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], birch_mean[START_LIMIT:END_LIMIT], label='Birch')
plt.fill_between(birch_field['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]+birch_std[START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]-birch_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.legend()
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Reference Data (Flight 2)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="948">

# %% [markdown]
# ## Flight 3 (cloudy with rare sun in haze)

# %%
spruce_field = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F3_spruce.txt', sep="\t")
birch_field = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F3_birch.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

spruce_mean = spruce_field.iloc[:,2:12].mean(1)
spruce_std = spruce_field.iloc[:,2:12].std(1)
birch_mean = birch_field.iloc[:,2:12].mean(1)
birch_std = birch_field.iloc[:,2:12].std(1)

plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], spruce_mean[START_LIMIT:END_LIMIT], label='Spruce')
plt.fill_between(spruce_field['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]+spruce_std[START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]-spruce_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], birch_mean[START_LIMIT:END_LIMIT], label='Birch')
plt.fill_between(birch_field['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]+birch_std[START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]-birch_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.legend()
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Reference Data (Flight 3)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="910">

# %% [markdown]
# ## Flight 4 (cloudy with rare sun in haze)

# %%
spruce_field = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F4_spruce.txt', sep="\t")
birch_field = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F4_birch.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

spruce_mean = spruce_field.iloc[:,2:12].mean(1)
spruce_std = spruce_field.iloc[:,2:12].std(1)
birch_mean = birch_field.iloc[:,2:12].mean(1)
birch_std = birch_field.iloc[:,2:12].std(1)

plt.plot(spruce_field['Wavelength'][START_LIMIT:END_LIMIT], spruce_mean[START_LIMIT:END_LIMIT], label='Spruce')
plt.fill_between(spruce_field['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]+spruce_std[START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]-spruce_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_field['Wavelength'][START_LIMIT:END_LIMIT], birch_mean[START_LIMIT:END_LIMIT], label='Birch')
plt.fill_between(birch_field['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]+birch_std[START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]-birch_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.legend()
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Reference Data (Flight 4)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="926">

# %% [markdown]
# ## Compare Different Flights

# %%
START_LIMIT = 100
END_LIMIT = 550

# %%
# spruce_1 = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F1_spruce.txt', sep="\t")
spruce_2 = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F2_spruce.txt', sep="\t")
spruce_3 = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F3_spruce.txt', sep="\t")
spruce_4 = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F4_spruce.txt', sep="\t")

birch_1 = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F1_birch.txt', sep="\t")
birch_2 = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F2_birch.txt', sep="\t")
birch_3 = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F3_birch.txt', sep="\t")
birch_4 = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/F4_birch.txt', sep="\t")

# %%
spruce_2_values = spruce_2.iloc[:,2:12].divide(spruce_2.iloc[:,[1,12]].mean(1), axis=0)
spruce_3_values = spruce_3.iloc[:,2:12].divide(spruce_3.iloc[:,[1,12]].mean(1), axis=0)
spruce_4_values = spruce_4.iloc[:,2:12].divide(spruce_4.iloc[:,[1,12]].mean(1), axis=0)

birch_1_values = birch_1.iloc[:,2:12].divide(birch_1.iloc[:,[1,12]].mean(1), axis=0)
birch_2_values = birch_2.iloc[:,2:12].divide(birch_2.iloc[:,[1,12]].mean(1), axis=0)
birch_3_values = birch_3.iloc[:,2:12].divide(birch_3.iloc[:,[1,12]].mean(1), axis=0)
birch_4_values = birch_4.iloc[:,2:12].divide(birch_4.iloc[:,[1,12]].mean(1), axis=0)

# %%
birch_1_mean = birch_1_values.mean(1)
birch_1_std = birch_1_values.std(1)
birch_2_mean = birch_2_values.mean(1)
birch_2_std = birch_2_values.std(1)
birch_3_mean = birch_3_values.mean(1)
birch_3_std = birch_3_values.std(1)
birch_4_mean = birch_4_values.mean(1)
birch_5_std = birch_4_values.std(1)

spruce_2_mean = spruce_2_values.mean(1)
spruce_2_std = spruce_2_values.std(1)
spruce_3_mean = spruce_3_values.mean(1)
spruce_3_std = spruce_3_values.std(1)
spruce_4_mean = spruce_4_values.mean(1)
spruce_5_std = spruce_4_values.std(1)

plt.plot(birch_1['Wavelength'][START_LIMIT:END_LIMIT], birch_1_mean[START_LIMIT:END_LIMIT], label='Flight 1 Birch')
plt.fill_between(birch_1['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_1_mean[START_LIMIT:END_LIMIT]+birch_1_std[START_LIMIT:END_LIMIT],
                 birch_1_mean[START_LIMIT:END_LIMIT]-birch_1_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_2['Wavelength'][START_LIMIT:END_LIMIT], birch_2_mean[START_LIMIT:END_LIMIT], label='Flight 2 Birch')
plt.fill_between(birch_2['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_2_mean[START_LIMIT:END_LIMIT]+birch_2_std[START_LIMIT:END_LIMIT],
                 birch_2_mean[START_LIMIT:END_LIMIT]-birch_2_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_3['Wavelength'][START_LIMIT:END_LIMIT], birch_3_mean[START_LIMIT:END_LIMIT], label='Flight 3 Birch')
plt.fill_between(birch_3['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_3_mean[START_LIMIT:END_LIMIT]+birch_3_std[START_LIMIT:END_LIMIT],
                 birch_3_mean[START_LIMIT:END_LIMIT]-birch_3_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_4['Wavelength'][START_LIMIT:END_LIMIT], birch_4_mean[START_LIMIT:END_LIMIT], label='Flight 4 Birch')
plt.fill_between(birch_4['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_4_mean[START_LIMIT:END_LIMIT]+birch_4_std[START_LIMIT:END_LIMIT],
                 birch_4_mean[START_LIMIT:END_LIMIT]-birch_4_std[START_LIMIT:END_LIMIT], alpha=0.2)

plt.plot(spruce_2['Wavelength'][START_LIMIT:END_LIMIT], spruce_2_mean[START_LIMIT:END_LIMIT], label='Flight 2 Spruce')
plt.fill_between(spruce_2['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_2_mean[START_LIMIT:END_LIMIT]+spruce_2_std[START_LIMIT:END_LIMIT],
                 spruce_2_mean[START_LIMIT:END_LIMIT]-spruce_2_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(spruce_3['Wavelength'][START_LIMIT:END_LIMIT], spruce_3_mean[START_LIMIT:END_LIMIT], label='Flight 3 Spruce')
plt.fill_between(spruce_3['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_3_mean[START_LIMIT:END_LIMIT]+spruce_3_std[START_LIMIT:END_LIMIT],
                 spruce_3_mean[START_LIMIT:END_LIMIT]-spruce_3_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(spruce_4['Wavelength'][START_LIMIT:END_LIMIT], spruce_4_mean[START_LIMIT:END_LIMIT], label='Flight 4 Spruce')
plt.fill_between(spruce_4['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_4_mean[START_LIMIT:END_LIMIT]+spruce_4_std[START_LIMIT:END_LIMIT],
                 spruce_4_mean[START_LIMIT:END_LIMIT]-spruce_4_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.legend()
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Reference Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="938">

# %% [markdown]
# ## Pure Spectrum Collection

# %%
spruce_needles = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/Spruce_pines.txt', sep="\t")

# %%
spruce_needles['Wavelength'][100]
# Out:
# 450

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_needles['Spoose_pines_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_needles['Spoose_pines_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_needles['Spoose_pines_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_needles['Spoose_pines_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_needles['Spoose_pines_00005.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Spruce Needles')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="885">

# %%
spruce_sticks = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/Spruce_sticks.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(spruce_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_sticks['Spoose_sticks_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_sticks['Spoose_sticks_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_sticks['Spoose_sticks_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_sticks['Spoose_sticks_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(spruce_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         spruce_sticks['Spoose_sticks_00005.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Spruce Sticks')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="893">

# %%
fir_needles = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/Fir_pines.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(fir_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_needles['Fir_pines_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(fir_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_needles['Fir_pines_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(fir_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_needles['Fir_pines_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(fir_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_needles['Fir_pines_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(fir_needles['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_needles['Fir_pines_00005.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Fir Needles')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899">

# %%
fir_sticks = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/Fir_sticks.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(fir_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_sticks['Fir_sticks_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(fir_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_sticks['Fir_sticks_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(fir_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_sticks['Fir_sticks_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(fir_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_sticks['Fir_sticks_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(fir_sticks['Wavelength'][START_LIMIT:END_LIMIT], 
         fir_sticks['Fir_sticks_00005.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Fir Sticks')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="899">

# %%
birch_green_leaves = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/Birch_green_leaves.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_green_leaves['Birch_green_leaves_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_green_leaves['Birch_green_leaves_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_green_leaves['Birch_green_leaves_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_green_leaves['Birch_green_leaves_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_green_leaves['Birch_green_leaves_00005.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Birch Green Leaves')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="931">

# %%
birch_yellow_leaves = pd.read_csv(REFERENCE_PATH+'FieldSpec3/21082018/TXT/Birch_yellow_leaves.txt', sep="\t")

# %%
START_LIMIT = 100
END_LIMIT = 550

plt.plot(birch_yellow_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_yellow_leaves['Birch_yellow_leaves_00001.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_yellow_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_yellow_leaves['Birch_yellow_leaves_00002.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_yellow_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_yellow_leaves['Birch_yellow_leaves_00003.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_yellow_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_yellow_leaves['Birch_yellow_leaves_00004.asd'][START_LIMIT:END_LIMIT])
plt.plot(birch_yellow_leaves['Wavelength'][START_LIMIT:END_LIMIT], 
         birch_yellow_leaves['Birch_yellow_leaves_00005.asd'][START_LIMIT:END_LIMIT])
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Birch Yellow Leaves')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="911">

# %%
spruce_values = spruce_needles.iloc[:,2:7].divide(spruce_needles.iloc[:,[1,7]].mean(1), axis=0)
fir_values = fir_needles.iloc[:,2:7].divide(spruce_3.iloc[:,[1,7]].mean(1), axis=0)
birch_values = birch_green_leaves.iloc[:,2:7].divide(spruce_4.iloc[:,[1,7]].mean(1), axis=0)

# %%
spruce_mean = spruce_values.mean(1)
spruce_std = spruce_values.std(1)
fir_mean = fir_values.mean(1)
fir_std = fir_values.std(1)
birch_mean = birch_values.mean(1)
birch_std = birch_values.std(1)

plt.plot(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT], spruce_mean[START_LIMIT:END_LIMIT],
         label='Spruce')
plt.fill_between(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]+spruce_std[START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]-spruce_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(fir_needles['Wavelength'][START_LIMIT:END_LIMIT], fir_mean[START_LIMIT:END_LIMIT],
         label='Fir')
plt.fill_between(fir_needles['Wavelength'][START_LIMIT:END_LIMIT],
                 fir_mean[START_LIMIT:END_LIMIT]+fir_std[START_LIMIT:END_LIMIT],
                 fir_mean[START_LIMIT:END_LIMIT]-fir_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT], birch_mean[START_LIMIT:END_LIMIT],
         label='Birch')
plt.fill_between(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]+birch_std[START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]-birch_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.legend()
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Pure Spectrum')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="915">

# %%
plt.plot(birch_1['Wavelength'][START_LIMIT:END_LIMIT], birch_1_mean[START_LIMIT:END_LIMIT], label='Flight 1 Birch')
plt.fill_between(birch_1['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_1_mean[START_LIMIT:END_LIMIT]+birch_1_std[START_LIMIT:END_LIMIT],
                 birch_1_mean[START_LIMIT:END_LIMIT]-birch_1_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_2['Wavelength'][START_LIMIT:END_LIMIT], birch_2_mean[START_LIMIT:END_LIMIT], label='Flight 2 Birch')
plt.fill_between(birch_2['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_2_mean[START_LIMIT:END_LIMIT]+birch_2_std[START_LIMIT:END_LIMIT],
                 birch_2_mean[START_LIMIT:END_LIMIT]-birch_2_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_3['Wavelength'][START_LIMIT:END_LIMIT], birch_3_mean[START_LIMIT:END_LIMIT], label='Flight 3 Birch')
plt.fill_between(birch_3['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_3_mean[START_LIMIT:END_LIMIT]+birch_3_std[START_LIMIT:END_LIMIT],
                 birch_3_mean[START_LIMIT:END_LIMIT]-birch_3_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_4['Wavelength'][START_LIMIT:END_LIMIT], birch_4_mean[START_LIMIT:END_LIMIT], label='Flight 4 Birch')
plt.fill_between(birch_4['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_4_mean[START_LIMIT:END_LIMIT]+birch_4_std[START_LIMIT:END_LIMIT],
                 birch_4_mean[START_LIMIT:END_LIMIT]-birch_4_std[START_LIMIT:END_LIMIT], alpha=0.2)

plt.plot(spruce_2['Wavelength'][START_LIMIT:END_LIMIT], spruce_2_mean[START_LIMIT:END_LIMIT], label='Flight 2 Spruce')
plt.fill_between(spruce_2['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_2_mean[START_LIMIT:END_LIMIT]+spruce_2_std[START_LIMIT:END_LIMIT],
                 spruce_2_mean[START_LIMIT:END_LIMIT]-spruce_2_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(spruce_3['Wavelength'][START_LIMIT:END_LIMIT], spruce_3_mean[START_LIMIT:END_LIMIT], label='Flight 3 Spruce')
plt.fill_between(spruce_3['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_3_mean[START_LIMIT:END_LIMIT]+spruce_3_std[START_LIMIT:END_LIMIT],
                 spruce_3_mean[START_LIMIT:END_LIMIT]-spruce_3_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(spruce_4['Wavelength'][START_LIMIT:END_LIMIT], spruce_4_mean[START_LIMIT:END_LIMIT], label='Flight 4 Spruce')
plt.fill_between(spruce_4['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_4_mean[START_LIMIT:END_LIMIT]+spruce_4_std[START_LIMIT:END_LIMIT],
                 spruce_4_mean[START_LIMIT:END_LIMIT]-spruce_4_std[START_LIMIT:END_LIMIT], alpha=0.2)

plt.plot(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT], spruce_mean[START_LIMIT:END_LIMIT],
         label='Spruce Needles Pure')
plt.fill_between(spruce_needles['Wavelength'][START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]+spruce_std[START_LIMIT:END_LIMIT],
                 spruce_mean[START_LIMIT:END_LIMIT]-spruce_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(fir_needles['Wavelength'][START_LIMIT:END_LIMIT], fir_mean[START_LIMIT:END_LIMIT],
         label='Fir Needles Pure')
plt.fill_between(fir_needles['Wavelength'][START_LIMIT:END_LIMIT],
                 fir_mean[START_LIMIT:END_LIMIT]+fir_std[START_LIMIT:END_LIMIT],
                 fir_mean[START_LIMIT:END_LIMIT]-fir_std[START_LIMIT:END_LIMIT], alpha=0.2)
plt.plot(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT], birch_mean[START_LIMIT:END_LIMIT],
         label='Birch Leaves Pure')
plt.fill_between(birch_green_leaves['Wavelength'][START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]+birch_std[START_LIMIT:END_LIMIT],
                 birch_mean[START_LIMIT:END_LIMIT]-birch_std[START_LIMIT:END_LIMIT], alpha=0.2)

plt.legend()
plt.xlabel('wavelength (nm)')
plt.ylabel('value')
plt.title('Reference Data')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="916">

# %% [markdown]
# # USGS Spectral Library

# %%
fir_01 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/fir/splib07a_Douglas-Fir_YNP-DF-1_forest_AVIRISb_RTGC/splib07a_Douglas-Fir_YNP-DF-1_forest_AVIRISb_RTGC.txt')
fir_bands_01 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/fir/splib07a_Douglas-Fir_YNP-DF-1_forest_AVIRISb_RTGC/splib07a_Wavelengths_AVIRIS_1996_0.37-2.5_microns.txt')

fir_02 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/fir/splib07a_Douglas-Fir_YNP-DF-2_forest_AVIRISb_RTGC/splib07a_Douglas-Fir_YNP-DF-2_forest_AVIRISb_RTGC.txt')
fir_bands_02 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/fir/splib07a_Douglas-Fir_YNP-DF-2_forest_AVIRISb_RTGC/splib07a_Wavelengths_AVIRIS_1996_0.37-2.5_microns.txt')

fir_03 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/fir/splib07a_Douglas-Fir_YNP-DF-3_forest_AVIRISb_RTGC/splib07a_Douglas-Fir_YNP-DF-3_forest_AVIRISb_RTGC.txt')
fir_bands_03 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/fir/splib07a_Douglas-Fir_YNP-DF-3_forest_AVIRISb_RTGC/splib07a_Wavelengths_AVIRIS_1996_0.37-2.5_microns.txt')

spruce_01 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/spruce/splib07a_Blue_Spruce_DW92-5_needles_BECKa_AREF/splib07a_Blue_Spruce_DW92-5_needles_BECKa_AREF.txt')
spruce_bands_01 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/spruce/splib07a_Blue_Spruce_DW92-5_needles_BECKa_AREF/splib07a_Wavelengths_BECK_Beckman_0.2-3.0_microns.txt')

spruce_02 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/spruce/splib07a_Engelmann-Spruce_ES-Needls-1_ASDFRa_AREF/splib07a_Engelmann-Spruce_ES-Needls-1_ASDFRa_AREF.txt')
spruce_bands_02 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/spruce/splib07a_Engelmann-Spruce_ES-Needls-1_ASDFRa_AREF/splib07a_Wavelengths_ASD_0.35-2.5_microns_2151_ch.txt')

spruce_and_fir_01 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/spruce_and_fir/splib07a_Espruce-Sfir_YNP-SF-1_forst_AVIRISb_RTGC/splib07a_Espruce-Sfir_YNP-SF-1_forst_AVIRISb_RTGC.txt')
spruce_and_fir_bands_01 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/spruce_and_fir/splib07a_Espruce-Sfir_YNP-SF-1_forst_AVIRISb_RTGC/splib07a_Wavelengths_AVIRIS_1996_0.37-2.5_microns.txt')

spruce_and_fir_02 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/spruce_and_fir/splib07a_Espruce-Sfir_YNP-SF-2_forst_AVIRISb_RTGC/splib07a_Espruce-Sfir_YNP-SF-2_forst_AVIRISb_RTGC.txt')
spruce_and_fir_bands_02 = pd.read_csv('/Users/vasilii.mosin/Desktop/ForestHype/data/spectrums/usgs/spruce_and_fir/splib07a_Espruce-Sfir_YNP-SF-2_forst_AVIRISb_RTGC/splib07a_Wavelengths_AVIRIS_1996_0.37-2.5_microns.txt')

# %%
fir_bands_01 = fir_bands_01[fir_01.iloc[:,0] != -1.230000e+34]
fir_bands_02 = fir_bands_02[fir_02.iloc[:,0] != -1.230000e+34]
fir_bands_03 = fir_bands_03[fir_03.iloc[:,0] != -1.230000e+34]

spruce_bands_01 = spruce_bands_01[spruce_01.iloc[:,0] != -1.230000e+34]
spruce_bands_02 = spruce_bands_02[spruce_02.iloc[:,0] != -1.230000e+34]

spruce_and_fir_bands_01 = spruce_and_fir_bands_01[spruce_and_fir_01.iloc[:,0] != -1.230000e+34]
spruce_and_fir_bands_02 = spruce_and_fir_bands_02[spruce_and_fir_02.iloc[:,0] != -1.230000e+34]

# %%
fir_01 = fir_01[fir_01.iloc[:,0] != -1.230000e+34]
fir_02 = fir_02[fir_02.iloc[:,0] != -1.230000e+34]
fir_03 = fir_02[fir_02.iloc[:,0] != -1.230000e+34]

spruce_01 = spruce_01[spruce_01.iloc[:,0] != -1.230000e+34]
spruce_02 = spruce_02[spruce_02.iloc[:,0] != -1.230000e+34]

spruce_and_fir_01 = spruce_and_fir_01[spruce_and_fir_01.iloc[:,0] != -1.230000e+34]
spruce_and_fir_02 = spruce_and_fir_02[spruce_and_fir_02.iloc[:,0] != -1.230000e+34]

# %%
plt.figure(figsize=(9,4))

plt.plot(fir_bands_01, fir_01, c='blue')
plt.plot(fir_bands_02, fir_02, c='blue')

# plt.plot(spruce_bands_01, spruce_01, c='green')
# plt.plot(spruce_bands_02, spruce_02, c='green')

plt.plot(spruce_and_fir_bands_01, spruce_and_fir_01, c='red')
plt.plot(spruce_and_fir_bands_02, spruce_and_fir_02, c='red')

plt.xlabel('wavelength (\u03BCm)')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="900">
